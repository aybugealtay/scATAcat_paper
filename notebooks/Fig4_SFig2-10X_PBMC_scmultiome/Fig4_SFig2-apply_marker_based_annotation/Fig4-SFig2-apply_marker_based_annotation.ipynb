# %%
import pickle
import numpy as np
import scanpy as sc
import pandas as pd
import matplotlib.pylab as plt
import os 
import warnings
import seaborn as sns
import random as rn
import matplotlib
import scATAcat

# %% [markdown]
# #### define necessary parameters

# %%
# set the seed for reproducibility
sd = 1234
np.random.seed(sd)
rn.seed(sd)
# %env PYTHONHASHSEED=0
# Out:
# env: PYTHONHASHSEED=0

# %% [markdown]
# #### define necessary parameters

# %%
warnings.filterwarnings('ignore')

figures_dir = "../../../results/Fig4_SFig2-10X_PBMC_scmultiome/Fig4_SFig2-apply_marker_based_annotation/figures/"
data_dir = "../../../results/Fig4_SFig2-10X_PBMC_scmultiome/"

if not os.path.exists(figures_dir):
    os.makedirs(figures_dir)

# %% [markdown]
# #### define necessary parameters

# %% [markdown]
# #### import scanpy object

# %%
sc_commonDiffFeatures_adata= pickle.load(open(data_dir +'Fig4_SFig2-apply_scATAcat/outputs/sc_commonDiffFeatures_adata.pkl','rb'))

# %%
pbmc_atac_activity_matrix = pd.read_csv(data_dir + "Fig4_SFig2-apply_seurat_label_transfer/PBMC_atac_gene_activities.csv", index_col=0)
pbmc_atac_activity_matrix.head()
# Out:
#          AAACAGCCAAGGAATC-1  AAACAGCCAATCCCTT-1  AAACAGCCAATGCGCT-1  \
# PLCXD1                    1                   2                   0
# GTPBP6                    3                   4                   0
# PPP2R3B                   2                   1                   2
# SHOX                      0                   0                   0
# CRLF2                     0                   0                   0
#
#          AAACAGCCACCAACCG-1  AAACAGCCAGGATAAC-1  AAACAGCCAGTAGGTG-1  \
# PLCXD1                    0                   1                   0
# GTPBP6                    0                   0                   5
# PPP2R3B                   0                   1                   6
# SHOX                      0                   0                   0
# CRLF2                     0                   0                   0
#
#          AAACAGCCAGTTTACG-1  AAACAGCCATCCAGGT-1  AAACATGCAAGGTCCT-1  \
# PLCXD1                    0                   4                   1
# ...

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="CD19", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/CD19_gene_act_B_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="MS4A1", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/MS4A1_gene_act_B_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="CD4", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/CD4_gene_act_CD4T_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="IL7R", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/IL7R_gene_act_CD4T_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="CCR7", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/CCR7_gene_act_CD4T_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="CTLA4", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/CTLA4_gene_act_CD4T_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="HLA-DR", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/HLA-DR_gene_act_Mono_marker.pdf",
                           cmap= None)
plt.show()
# Out:
# this gene is not included in the gene activity matrix

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="MPO", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/MPO_gene_act_Mono_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="CD27", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/CD27_gene_act_B_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="LYZ", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/LYZ_gene_act_Mono_marker.pdf",
                           cmap= None)
plt.show()

# %% [markdown]
# ### UMAP embedding colored by groudn-truth cell-type identities

# %%
seurat_label_transfer_annotations = pd.read_csv(data_dir + "Fig4_SFig2-apply_seurat_label_transfer/10XPBMC_seurat_label_transfer_annotations.csv")
seurat_label_transfer_annotations.columns =["cell_IDs", "label_transfer_ann", "ground_truth_ann"]
seurat_label_transfer_annotations
# Out:
#                  cell_IDs label_transfer_ann ground_truth_ann
# 0      AAACAGCCAAGGAATC-1              CD4 T            CD4 T
# 1      AAACAGCCAATCCCTT-1              CD8 T            CD4 T
# 2      AAACAGCCAATGCGCT-1              CD8 T            CD4 T
# 3      AAACAGCCACCAACCG-1               Mono            CD8 T
# 4      AAACAGCCAGGATAAC-1              CD4 T            CD4 T
# ...                   ...                ...              ...
# 10407  TTTGTTGGTGACATGC-1              CD8 T            CD8 T
# 10408  TTTGTTGGTGTTAAAC-1              CD8 T            CD8 T
# 10409  TTTGTTGGTTAGGATT-1                 NK               NK
# 10410  TTTGTTGGTTGGTTAG-1              CD4 T            CD4 T
# 10411  TTTGTTGGTTTGCAGA-1              CD8 T            CD8 T
#
# [10412 rows x 3 columns]

# %%
test_df = sc_commonDiffFeatures_adata.obs

# %%
sc_commonDiffFeatures_adata.obs.index.name =None
sc_commonDiffFeatures_adata.obs = pd.merge(test_df, seurat_label_transfer_annotations, on="cell_IDs")

# %%
sc_commonDiffFeatures_adata.obs.columns
# Out:
# Index(['cell_IDs', 'leiden_1.0', 'num_feature_per_cell_', 'CD19', 'MS4A1',
#        'CD4', 'IL7R', 'CCR7', 'CTLA4', 'MPO', 'CD27', 'LYZ',
#        'label_transfer_ann', 'ground_truth_ann'],
#       dtype='object')

# %%
 pd.merge(test_df, seurat_label_transfer_annotations, on="cell_IDs")
# Out:
#                 cell_IDs leiden_1.0  num_feature_per_cell_  CD19  MS4A1  \
# 0     AAACAGCCAATCCCTT-1          4                11120.0   0.0    0.0
# 1     AAACAGCCAATGCGCT-1          2                 9380.0   0.0    0.0
# 2     AAACAGCCACCAACCG-1          1                 4285.0   0.0    0.0
# 3     AAACAGCCAGGATAAC-1          2                 5766.0   0.0    0.0
# 4     AAACAGCCAGTTTACG-1          4                10817.0   0.0    0.0
# ...                  ...        ...                    ...   ...    ...
# 9663  TTTGTTGGTGACATGC-1          1                 8449.0   0.0    0.0
# 9664  TTTGTTGGTGTTAAAC-1          1                10024.0   0.0    0.0
# 9665  TTTGTTGGTTAGGATT-1          9                 6009.0   0.0    0.0
# 9666  TTTGTTGGTTGGTTAG-1          6                 9541.0   0.0    0.0
# 9667  TTTGTTGGTTTGCAGA-1          5                11662.0   0.0    0.0
#
#            CD4      IL7R      CCR7     CTLA4  MPO      CD27  LYZ  \
# ...

# %%
with plt.rc_context():
    sc.pl.umap(sc_commonDiffFeatures_adata, color='ground_truth_ann', show=False,size=15 , add_outline=False, frameon=False, title="",palette="tab20")
    plt.savefig(figures_dir + "/UMAP_colored_ground_truth.pdf", bbox_inches="tight")

# %%
plt.show()

# %%
sc_commonDiffFeatures_adata.uns["ground_truth_ann_colors"] =['#38184C', "#275974", "#82018F",  "#7ED9B7", "#008F8C", "#D46A00",'#F5206A','#97EEF5']

# %%
sc_commonDiffFeatures_adata.uns["ground_truth_ann_colors"]
# Out:
# ['#38184C',
#  '#275974',
#  '#82018F',
#  '#7ED9B7',
#  '#008F8C',
#  '#D46A00',
#  '#F5206A',
#  '#97EEF5']

# %%
sc_commonDiffFeatures_adata.uns.keys()
# Out:
# odict_keys(['pca', 'neighbors', 'umap', 'leiden', 'leiden_1.0_colors', 'ground_truth_ann_colors'])

# %%
with plt.rc_context():
    sc.pl.umap(sc_commonDiffFeatures_adata, color='ground_truth_ann', show=False,size=15 , add_outline=False, frameon=False, title="")
    plt.savefig(figures_dir + "/UMAP_colored_ground_truth_matchingcolor.pdf", bbox_inches="tight")

# %%
plt.show()
