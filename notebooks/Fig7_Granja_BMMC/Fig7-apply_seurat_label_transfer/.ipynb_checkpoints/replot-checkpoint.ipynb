# %%
suppressMessages({library(Seurat) 
library(SeuratData)
library(Signac)
library(EnsDb.Hsapiens.v86)
library(ggplot2)
library(cowplot)
library(GenomeInfoDb)
library(stringr)
library(patchwork)
library(SeuratDisk)
library(dplyr)})

# %%
bmmc.atac = readRDS("/project/scATAC_analysis/scATAcat_review/results/Fig7-Granja_BMMC_scATAC/Fig7-apply_seurat_label_transfer/WS/bmmc_atac")

# %%
atac_plot <- DimPlot(bmmc.atac, reduction = 'umap.atac', group.by = 'predicted.celltype.l2', label = TRUE, 
              repel = TRUE, label.size = 4, ) + scale_fill_continuous(guide = guide_legend()) +
    theme(legend.position="bottom")

# %%
atac_plot
# Out:
# plot without title

# %%
ggsave("atac_plot.pdf", plot = atac_plot, width = 10, height = 8, units = "in")
