# %%
import pickle
import numpy as np
import scanpy as sc
import pandas as pd
import matplotlib.pylab as plt
import os 
import warnings
import seaborn as sns
import random as rn
import matplotlib
import scATAcat

# %% [markdown]
# #### define necessary parameters

# %%
# set the seed for reproducibility
sd = 1234
np.random.seed(sd)
rn.seed(sd)
# %env PYTHONHASHSEED=0
# Out:
# env: PYTHONHASHSEED=0

# %% [markdown]
# #### define necessary parameters

# %%
warnings.filterwarnings('ignore')

figures_dir = "../../../results/Fig6-Granja_PBMC_scATAC/Fig6-apply_marker_based_annotation/figures/"
data_dir = "../../../results/Fig6-Granja_PBMC_scATAC/"

if not os.path.exists(figures_dir):
    os.makedirs(figures_dir)

# %%
def get_common_cells(*dataframes):
    df_cell_list = [v.index for v in dataframes]
    common_cells= list(set.intersection(*map(set,df_cell_list)))
    return(common_cells)

# %% [markdown]
# #### define necessary parameters

# %% [markdown]
# #### import scanpy object

# %%
sc_commonDiffFeatures_adata= pickle.load(open(data_dir +'Fig6-apply_scATAcat/outputs/sc_commonDiffFeatures_adata.pkl','rb'))

# %%
sc_commonDiffFeatures_adata
# Out:
# AnnData object with n_obs × n_vars = 2682 × 18851
#     obs: 'cell_IDs', 'leiden_1.0', 'num_feature_per_cell_'
#     var: 'cCREs'
#     uns: 'pca', 'neighbors', 'umap', 'leiden', 'leiden_1.0_colors'
#     obsm: 'num_feature_per_cell', 'X_pca', 'X_umap'
#     varm: 'num_cell_per_feature', 'PCs'
#     layers: 'binary', 'TF_logIDF'
#     obsp: 'distances', 'connectivities'

# %%
pbmc_atac_activity_matrix = pd.read_csv(data_dir + "Fig6-apply_seurat_label_transfer/PBMC_atac_gene_activities.csv", index_col=0)
pbmc_atac_activity_matrix = pbmc_atac_activity_matrix

# %%
pbmc_atac_activity_matrix.head()
# Out:
#          TGCATGACAGGCTACC-1  GGTGTCGCATGGTATC-1  TGACAACTCGCAAGCC-1  \
# PLCXD1                    1                   0                   0
# GTPBP6                    1                   1                   0
# PPP2R3B                   1                   2                   0
# SHOX                      0                   0                   0
# CRLF2                     0                   1                   1
#
#          GTTGGGCCATGGCCGT-1  GCCATAATCATACTTC-1  AACCTTTAGCGCATTT-1  \
# PLCXD1                    1                   0                   0
# GTPBP6                    0                   0                   0
# PPP2R3B                   0                   2                   0
# SHOX                      0                   0                   0
# CRLF2                     0                   2                   0
#
#          ATCCAGATCGCGCTGA-1  GGGTTATCATCACAAC-1  GCCCGAAGTATGTTCG-1  \
# PLCXD1                    0                   0                   1
# GTPBP6                    0                   0                   0
# PPP2R3B                   4                   1                   2
# SHOX                      3                   0                   0
# CRLF2                     0                   0                   0
#
#          CTGTATTGTCACCCGA-1  ...  CAACCAACAAAGAGAG-1  TCGAGCGCAGATAAGT-1  \
# PLCXD1                    1  ...                   0                   0
# GTPBP6                    4  ...                   0                   0
# PPP2R3B                   2  ...                   0                   0
# SHOX                      0  ...                   0                   0
# CRLF2                     0  ...                   0                   0
#
#          CACAACAGTTGCTTGA-1  CACAACATCGATGTGT-1  ACAAACCTCTCCTTGG-1  \
# PLCXD1                    0                   0                   0
# GTPBP6                    0                   0                   0
# PPP2R3B                   0                   2                   0
# SHOX                      0                   0                   0
# CRLF2                     0                   0                   0
#
#          AACTGTGGTGGACTGA-1  AGTGCGCCACGATTAC-1  TGCTTCGCATGGCCTG-1  \
# PLCXD1                    1                   0                   1
# GTPBP6                    0                   0                   1
# PPP2R3B                   0                   0                   0
# SHOX                      0                   0                   0
# CRLF2                     0                   0                   0
#
#          AGCGATTAGAGAAGCA-1  TCCATCGTCACATTCT-1
# PLCXD1                    0                   0
# GTPBP6                    0                   0
# PPP2R3B                   0                   1
# SHOX                      0                   0
# CRLF2                     0                   0
#
# [5 rows x 2607 columns]

# %% [markdown]
# ## get the gorund truth cell types

# %%
ground_truth_annotations = pd.read_csv("../../../data/Granja2019/PBMC_D10T1/03_cellIDs_and_annotations/metadata.csv")

# %%
ground_truth_annotations = ground_truth_annotations[["BioClassification", "Barcode"]]
ground_truth_annotations[['cluster_id', 'annotation']] = ground_truth_annotations['BioClassification'].str.split('_', n=1, expand=True)
ground_truth_annotations.index=ground_truth_annotations['Barcode']
ground_truth_annotations.index.name = None
ground_truth_annotations.columns = ["BioClassification","cell_IDs","cluster_id","annotation"]

# %%
ground_truth_renaming_dict={'B':'Bcell',
 'CD14.Mono.1':'Mono',
 'CD14.Mono.2':'Mono',
 'CD4.M':'CD4Tcell',
 'CD4.N1':'CD4Tcell',
 'CD4.N2':'CD4Tcell',
 'CD8.CM':'CD8Tcell',
 'CD8.EM':'CD8Tcell',
 'CD8.N':'CD8Tcell',
 'Early.Baso':'Basofil',
 'GMP':'GMP',
 'HSC':'HSC/MPP',
 'NK':'NKcell',
 'Plasma':'Plasmacell',
 'Unk':'Unknown',
 'cDC':'DC',
 'pDC':'DC',
 'CLP.1': 'CLP',
 'CLP.2': 'CLP',
 'CMP.LMPP': 'CMP/LMPP',
 'Early.Eryth': 'Ery',
 'GMP.Neut': 'GMP',
 'Late.Eryth': 'Ery',
 'Pre.B': 'CLP'}

# %% [raw]
# ground_truth_renaming_dict={'B':'B',
#  'CD14.Mono.1':'Mono',
#  'CD14.Mono.2':'Mono',
#  'CD4.M':'CD4 T',
#  'CD4.N1':'CD4 T',
#  'CD4.N2':'CD4 T',
#  'CD8.CM':'CD8 T',
#  'CD8.EM':'CD8 T',
#  'CD8.N':'CD8 T',
#  'Early.Baso':'Basofil',
#  'GMP':'GMP',
#  'HSC':'HSC/MPP',
#  'NK':'NK',
#  'Plasma':'Plasmacell',
#  'Unk':'Unknown',
#  'cDC':'DC',
#  'pDC':'DC'}

# %%
ground_truth_annotations= ground_truth_annotations.assign(ground_truth_annotations_simplified=list(ground_truth_annotations['annotation'].map(ground_truth_renaming_dict)))
ground_truth_annotations.head()
# Out:
#                    BioClassification            cell_IDs cluster_id  \
# TCAGGGCAGGGCATTG-1         21_CD4.N2  TCAGGGCAGGGCATTG-1         21
# GTTCAAGCAGTTACAC-1          22_CD4.M  GTTCAAGCAGTTACAC-1         22
# CATTCCGGTGATAACA-1          22_CD4.M  CATTCCGGTGATAACA-1         22
# GCGTTGGTCCAGTTAG-1         21_CD4.N2  GCGTTGGTCCAGTTAG-1         21
# TCAAAGCCAAGCACTT-1            26_Unk  TCAAAGCCAAGCACTT-1         26
#
#                    annotation ground_truth_annotations_simplified
# TCAGGGCAGGGCATTG-1     CD4.N2                            CD4Tcell
# GTTCAAGCAGTTACAC-1      CD4.M                            CD4Tcell
# CATTCCGGTGATAACA-1      CD4.M                            CD4Tcell
# GCGTTGGTCCAGTTAG-1     CD4.N2                            CD4Tcell
# TCAAAGCCAAGCACTT-1        Unk                             Unknown

# %%
ground_truth_annotations_known = ground_truth_annotations[ground_truth_annotations['ground_truth_annotations_simplified']!= "Unknown"]

# %%
ground_truth_annotations.shape
# Out:
# (2891, 5)

# %%
ground_truth_annotations.annotation.value_counts()
# Out:
# annotation
# CD14.Mono.2    867
# CD4.N2         613
# CD4.M          434
# Unk            270
# B              221
# NK             168
# CD8.CM         107
# CD8.EM          83
# cDC             67
# Plasma          21
# pDC             15
# Early.Baso       8
# CD14.Mono.1      7
# CD4.N1           6
# GMP              2
# HSC              1
# CD8.N            1
# Name: count, dtype: int64

# %%
ground_truth_annotations.ground_truth_annotations_simplified.value_counts()
# Out:
# ground_truth_annotations_simplified
# CD4Tcell      1053
# Mono           874
# Unknown        270
# Bcell          221
# CD8Tcell       191
# NKcell         168
# DC              82
# Plasmacell      21
# Basofil          8
# GMP              2
# HSC/MPP          1
# Name: count, dtype: int64

# %%
ground_truth_annotations_known.head()
# Out:
#                    BioClassification            cell_IDs cluster_id  \
# TCAGGGCAGGGCATTG-1         21_CD4.N2  TCAGGGCAGGGCATTG-1         21
# GTTCAAGCAGTTACAC-1          22_CD4.M  GTTCAAGCAGTTACAC-1         22
# CATTCCGGTGATAACA-1          22_CD4.M  CATTCCGGTGATAACA-1         22
# GCGTTGGTCCAGTTAG-1         21_CD4.N2  GCGTTGGTCCAGTTAG-1         21
# TTGACGACATATAGAG-1    12_CD14.Mono.2  TTGACGACATATAGAG-1         12
#
#                      annotation ground_truth_annotations_simplified
# TCAGGGCAGGGCATTG-1       CD4.N2                            CD4Tcell
# GTTCAAGCAGTTACAC-1        CD4.M                            CD4Tcell
# CATTCCGGTGATAACA-1        CD4.M                            CD4Tcell
# GCGTTGGTCCAGTTAG-1       CD4.N2                            CD4Tcell
# TTGACGACATATAGAG-1  CD14.Mono.2                                Mono

# %% [markdown]
# ### get the common cells and subset the pbmc_atac_activity_matrix, as well as the AnnData object to these common cells

# %%
common_cells = get_common_cells(sc_commonDiffFeatures_adata.obs, pbmc_atac_activity_matrix.T,ground_truth_annotations_known)

# %%
len(common_cells)
# Out:
# 2430

# %%
sc_commonDiffFeatures_adata =  scATAcat.subset_adata_obs(sc_commonDiffFeatures_adata, obs_list= common_cells, copy_=False)

# %%
pbmc_atac_activity_matrix = pbmc_atac_activity_matrix[common_cells]

# %%
ground_truth_annotations_known_common = ground_truth_annotations_known.loc[common_cells]

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name='CD19', 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/CD19_gene_act_B_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="MS4A1", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/MS4A1_gene_act_B_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="PAX5", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/PAX5_gene_act_B_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="CD4", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/CD4_gene_act_CD4T_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="IL7R", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/IL7R_gene_act_CD4T_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="CCR7", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/CCR7_gene_act_CD4T_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="CTLA4", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/CTLA4_gene_act_CD4T_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="HLA-DR", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/HLA-DR_gene_act_Mono_marker.pdf",
                           cmap= None)
plt.show()
# Out:
# this gene is not included in the gene activity matrix

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="MPO", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/MPO_gene_act_Mono_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="CD27", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/CD27_gene_act_B_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="LYZ", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/LYZ_gene_act_Mono_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="CD8B", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/CD8b_gene_act_CD8T_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="CD8A", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/CD8A_gene_act_CD8T_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="GZMK", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/GZMK_gene_act_CD8T_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="CCR7", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/CCR7_gene_act_CD8T_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="FCER1A", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/FCER1A_gene_act_DC_marker.pdf",
                           cmap= None)
plt.show()

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="CD303﻿", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/CD303_gene_act_DC_marker.pdf",
                           cmap= None)
plt.show()
# Out:
# this gene is not included in the gene activity matrix

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="CD1c﻿", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/CD1c_gene_act_DC_marker.pdf",
                           cmap= None)
plt.show()
# Out:
# this gene is not included in the gene activity matrix

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="CLEC9A﻿", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/CLEC9A_gene_act_DC_marker.pdf",
                           cmap= None)
plt.show()
# Out:
# this gene is not included in the gene activity matrix

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="GNLY﻿", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/GNLY_gene_act_NK_marker.pdf",
                           cmap= None)
plt.show()
# Out:
# this gene is not included in the gene activity matrix

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="﻿CD56﻿", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/CD56_gene_act_NK_marker.pdf",
                           cmap= None)
plt.show()
# Out:
# this gene is not included in the gene activity matrix

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="﻿CD567", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/CD57_gene_act_NK_marker.pdf",
                           cmap= None)
plt.show()
# Out:
# this gene is not included in the gene activity matrix

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="﻿CCL3﻿", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/CCL3_gene_act_NK_marker.pdf",
                           cmap= None)
plt.show()
# Out:
# this gene is not included in the gene activity matrix

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="﻿FGCR3A", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/FGCR3A_gene_act_NK_marker.pdf",
                           cmap= None)
plt.show()
# Out:
# this gene is not included in the gene activity matrix

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="﻿DUSP1", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/DUSP1_gene_act_NK_marker.pdf",
                           cmap= None)
plt.show()
# Out:
# this gene is not included in the gene activity matrix

# %%
scATAcat.plot_gene_activity_of_UMAP(adata=sc_commonDiffFeatures_adata, 
                           gene_name="﻿FOS", 
                           activity_matrix=pbmc_atac_activity_matrix,
                           out_path=figures_dir+"/FOS_gene_act_NK_marker.pdf",
                           cmap= None)
plt.show()
# Out:
# this gene is not included in the gene activity matrix

# %% [markdown]
# ### UMAP embedding colored by ground-truth cell-type identities

# %%
ground_truth_annotations_known.head()
# Out:
#                    BioClassification            cell_IDs cluster_id  \
# TCAGGGCAGGGCATTG-1         21_CD4.N2  TCAGGGCAGGGCATTG-1         21
# GTTCAAGCAGTTACAC-1          22_CD4.M  GTTCAAGCAGTTACAC-1         22
# CATTCCGGTGATAACA-1          22_CD4.M  CATTCCGGTGATAACA-1         22
# GCGTTGGTCCAGTTAG-1         21_CD4.N2  GCGTTGGTCCAGTTAG-1         21
# TTGACGACATATAGAG-1    12_CD14.Mono.2  TTGACGACATATAGAG-1         12
#
#                      annotation ground_truth_annotations_simplified
# TCAGGGCAGGGCATTG-1       CD4.N2                            CD4Tcell
# GTTCAAGCAGTTACAC-1        CD4.M                            CD4Tcell
# CATTCCGGTGATAACA-1        CD4.M                            CD4Tcell
# GCGTTGGTCCAGTTAG-1       CD4.N2                            CD4Tcell
# TTGACGACATATAGAG-1  CD14.Mono.2                                Mono

# %%
test_df = sc_commonDiffFeatures_adata.obs

# %%
sc_commonDiffFeatures_adata.obs.index.name =None
sc_commonDiffFeatures_adata.obs = pd.merge(test_df, ground_truth_annotations_known_common, on="cell_IDs")

# %%
sc_commonDiffFeatures_adata.obs.columns
# Out:
# Index(['cell_IDs', 'leiden_1.0', 'num_feature_per_cell_', 'CD19', 'MS4A1',
#        'PAX5', 'CD4', 'IL7R', 'CCR7', 'CTLA4', 'MPO', 'CD27', 'LYZ', 'CD8B',
#        'CD8A', 'GZMK', 'FCER1A', 'BioClassification', 'cluster_id',
#        'annotation', 'ground_truth_annotations_simplified'],
#       dtype='object')

# %%
with plt.rc_context():
    sc.pl.umap(sc_commonDiffFeatures_adata, color='ground_truth_annotations_simplified', show=False,size=15 , add_outline=False, frameon=False, title="",palette="tab20")
    plt.savefig(figures_dir + "/UMAP_colored_ground_truth.pdf", bbox_inches="tight")

# %%
plt.show()

# %%
sc_commonDiffFeatures_adata.uns["ground_truth_annotations_simplified_colors"] =['#38184C',  "tab:red", "#82018F","#CA1ED4", "#BDB0D9", "tab:gray", "#275974","#008F8C",'#3D5B9F','#D46A00',"tab:red","coral",'#C2EA8C',"#7ED9B7",'goldenrod']

# %%
#sc_commonDiffFeatures_adata.uns["ground_truth_annotations_simplified_colors"]= ['#38184C', "#275974", "#82018F",  "#7ED9B7", "#008F8C", "#D46A00",'#F5206A','#97EEF5']

# %%
#sc_commonDiffFeatures_adata.uns["ground_truth_annotations_simplified_colors"] =['#38184C', "#275974", "#82018F",  "#7ED9B7", "#008F8C", "#D46A00",'#F5206A','#97EEF5']

# %%
sc_commonDiffFeatures_adata.uns.keys()
# Out:
# odict_keys(['pca', 'neighbors', 'umap', 'leiden', 'leiden_1.0_colors', 'ground_truth_annotations_simplified_colors'])

# %%
with plt.rc_context():
    
    sc.pl.umap(sc_commonDiffFeatures_adata, color='ground_truth_annotations_simplified', show=False,size=22 , add_outline=False, frameon=False, title="")
    plt.savefig(figures_dir + "/UMAP_colored_ground_truth_matchingcolor.pdf", bbox_inches="tight")

# %%
plt.show()
